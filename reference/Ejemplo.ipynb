# %%
derivadas

lkklkjjkljkljkljkljlk
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1-601430727.py in <cell line: 0>()
# ----> 1 derivadas
#       2
#       3 lkklkjjkljkljkljkljlk
#
# NameError: name 'derivadas' is not defined

# %%
nombre = input("Introduce tu nombre: ")
print("¡Hola " + nombre + "!")
# Out:
# Introduce tu nombre: Luis
# ¡Hola Luis!
